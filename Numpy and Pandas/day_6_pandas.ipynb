# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("filtered_transactions.csv")

# df = pd.read_excel("filtered_transactions.xlsx",sheet_name=0)

df.to_csv("filtered_transactions.csv",index=False)

# %%
df
# Out:
#       customer_id         name transaction_date       amount category
# 0             732  Alice Brown       2023-11-09  1296.891576        C
# 1             497  Alice Brown       2022-07-11  1290.993794        -
# 2             682  Alice Brown       2022-06-01  1288.778254        A
# 3             906  Alice Brown       2023-04-12  1288.592427        A
# 4             497  Alice Brown       2023-04-27  1288.443606        B
# ...           ...          ...              ...          ...      ...
# 1045          167   John Smith       2023-09-02   711.596579        B
# 1046          973   John Smith       2023-09-23   710.531418        B
# 1047          895   John Smith       2023-09-20   710.168599        C
# 1048          451   John Smith       2023-09-09   705.954293        C
# 1049          369   John Smith       2023-09-27   700.812175        B
#
# [1050 rows x 5 columns]

# %% [markdown]
# ##### Summarize Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1050 non-null   int64
#  1   name              1050 non-null   object
#  2   transaction_date  1050 non-null   object
#  3   amount            1050 non-null   float64
#  4   category          1050 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.1+ KB

# %%
df.describe()
# Out:
#        customer_id       amount
# count  1050.000000  1050.000000
# mean    503.876190   999.641386
# std     291.250412   173.802633
# min       1.000000   700.080816
# 25%     239.500000   855.583776
# 50%     506.000000  1000.301415
# 75%     760.500000  1152.513524
# max     999.000000  1299.008507

# %%
df['amount'].describe()
# Out:
# count    1050.000000
# mean      999.641386
# std       173.802633
# min       700.080816
# 25%       855.583776
# 50%      1000.301415
# 75%      1152.513524
# max      1299.008507
# Name: amount, dtype: float64

# %% [markdown]
# ##### Sorting

# %%
df
# Out:
#       customer_id         name transaction_date       amount category
# 0             732  Alice Brown       2023-11-09  1296.891576        C
# 1             497  Alice Brown       2022-07-11  1290.993794        -
# 2             682  Alice Brown       2022-06-01  1288.778254        A
# 3             906  Alice Brown       2023-04-12  1288.592427        A
# 4             497  Alice Brown       2023-04-27  1288.443606        B
# ...           ...          ...              ...          ...      ...
# 1045          167   John Smith       2023-09-02   711.596579        B
# 1046          973   John Smith       2023-09-23   710.531418        B
# 1047          895   John Smith       2023-09-20   710.168599        C
# 1048          451   John Smith       2023-09-09   705.954293        C
# 1049          369   John Smith       2023-09-27   700.812175        B
#
# [1050 rows x 5 columns]

# %%
df.sort_values(by="amount", ascending=True)
# Out:
#       customer_id           name transaction_date       amount category
# 493           718     Bob Wilson       2023-07-10   700.080816        A
# 1049          369     John Smith       2023-09-27   700.812175        B
# 492           393     Bob Wilson       2022-12-26   700.939063        A
# 262           252    Alice Brown       2022-03-25   701.930958        A
# 261           144    Alice Brown       2023-07-15   702.291954        C
# ...           ...            ...              ...          ...      ...
# 0             732    Alice Brown       2023-11-09  1296.891576        C
# 264           470     Bob Wilson       2022-11-03  1297.262510        C
# 263           958     Bob Wilson       2022-03-17  1297.800603        B
# 494           253  Charlie Davis       2023-05-17  1298.692513        B
# 773           675     John Smith       2022-04-12  1299.008507        C
#
# [1050 rows x 5 columns]

# %%
df.sort_values(by="amount", ascending=False)
# Out:
#       customer_id           name transaction_date       amount category
# 773           675     John Smith       2022-04-12  1299.008507        C
# 494           253  Charlie Davis       2023-05-17  1298.692513        B
# 263           958     Bob Wilson       2022-03-17  1297.800603        B
# 264           470     Bob Wilson       2022-11-03  1297.262510        C
# 0             732    Alice Brown       2023-11-09  1296.891576        C
# ...           ...            ...              ...          ...      ...
# 261           144    Alice Brown       2023-07-15   702.291954        C
# 262           252    Alice Brown       2022-03-25   701.930958        A
# 492           393     Bob Wilson       2022-12-26   700.939063        A
# 1049          369     John Smith       2023-09-27   700.812175        B
# 493           718     Bob Wilson       2023-07-10   700.080816        A
#
# [1050 rows x 5 columns]

# %%
df.sort_values(by="name", ascending=True, inplace=True)

# %%
df
# Out:
#       customer_id         name transaction_date       amount category
# 0             732  Alice Brown       2023-11-09  1296.891576        C
# 167           161  Alice Brown       2022-01-17   923.300214        B
# 168           402  Alice Brown       2023-10-15   919.408449        A
# 169           930  Alice Brown       2022-04-23   917.341265        B
# 170           148  Alice Brown       2022-08-30   914.678959        C
# ...           ...          ...              ...          ...      ...
# 862           787   John Smith       2023-02-23  1112.964541        B
# 861           570   John Smith       2023-01-25  1115.495696        C
# 860           842   John Smith       2023-05-10  1115.519459        B
# 866           259   John Smith       2023-10-21  1104.478177        C
# 1049          369   John Smith       2023-09-27   700.812175        B
#
# [1050 rows x 5 columns]

# %%
df.sort_values(by=["name", "amount"], ascending=[True, False], inplace=True)

# %%
df
# Out:
#       customer_id         name transaction_date       amount category
# 0             732  Alice Brown       2023-11-09  1296.891576        C
# 1             497  Alice Brown       2022-07-11  1290.993794        -
# 2             682  Alice Brown       2022-06-01  1288.778254        A
# 3             906  Alice Brown       2023-04-12  1288.592427        A
# 4             497  Alice Brown       2023-04-27  1288.443606        B
# ...           ...          ...              ...          ...      ...
# 1045          167   John Smith       2023-09-02   711.596579        B
# 1046          973   John Smith       2023-09-23   710.531418        B
# 1047          895   John Smith       2023-09-20   710.168599        C
# 1048          451   John Smith       2023-09-09   705.954293        C
# 1049          369   John Smith       2023-09-27   700.812175        B
#
# [1050 rows x 5 columns]

# %% [markdown]
# ##### Filtering

# %%
df
# Out:
#       customer_id         name transaction_date       amount category
# 0             732  Alice Brown       2023-11-09  1296.891576        C
# 1             497  Alice Brown       2022-07-11  1290.993794        -
# 2             682  Alice Brown       2022-06-01  1288.778254        A
# 3             906  Alice Brown       2023-04-12  1288.592427        A
# 4             497  Alice Brown       2023-04-27  1288.443606        B
# ...           ...          ...              ...          ...      ...
# 1045          167   John Smith       2023-09-02   711.596579        B
# 1046          973   John Smith       2023-09-23   710.531418        B
# 1047          895   John Smith       2023-09-20   710.168599        C
# 1048          451   John Smith       2023-09-09   705.954293        C
# 1049          369   John Smith       2023-09-27   700.812175        B
#
# [1050 rows x 5 columns]

# %%
df[df["amount"] > 1000]
# Out:
#      customer_id         name transaction_date       amount category
# 0            732  Alice Brown       2023-11-09  1296.891576        C
# 1            497  Alice Brown       2022-07-11  1290.993794        -
# 2            682  Alice Brown       2022-06-01  1288.778254        A
# 3            906  Alice Brown       2023-04-12  1288.592427        A
# 4            497  Alice Brown       2023-04-27  1288.443606        B
# ..           ...          ...              ...          ...      ...
# 909          187   John Smith       2022-08-19  1016.439773        A
# 910          344   John Smith       2022-04-09  1010.361434        C
# 911          323   John Smith       2022-12-10  1007.600636        C
# 912          872   John Smith       2022-12-15  1004.447163        C
# 913          869   John Smith       2023-06-08  1000.374561        -
#
# [526 rows x 5 columns]

# %%
df["name"][df["amount"] > 1000]
# Out:
# 0      Alice Brown
# 1      Alice Brown
# 2      Alice Brown
# 3      Alice Brown
# 4      Alice Brown
#           ...
# 909     John Smith
# 910     John Smith
# 911     John Smith
# 912     John Smith
# 913     John Smith
# Name: name, Length: 526, dtype: object

# %%
df[(df["amount"] > 1000) & (df["category"] == "B")]
# Out:
#      customer_id         name transaction_date       amount category
# 4            497  Alice Brown       2023-04-27  1288.443606        B
# 12           870  Alice Brown       2023-12-17  1270.557157        B
# 14           420  Alice Brown       2023-06-05  1268.612816        B
# 15           973  Alice Brown       2022-06-15  1267.418888        B
# 16           699  Alice Brown       2022-05-29  1262.093477        B
# ..           ...          ...              ...          ...      ...
# 893          792   John Smith       2022-03-28  1047.990272        B
# 897          256   John Smith       2022-12-10  1043.229186        B
# 899          124   John Smith       2022-08-18  1035.853410        B
# 902          699   John Smith       2023-07-03  1031.500580        B
# 908          100   John Smith       2022-01-10  1018.181280        B
#
# [134 rows x 5 columns]

# %% [markdown]
# ##### Aggregation

# %%
print(df['amount'].min())
# Out:
# 700.080816

# %%
df['amount'].max()
# Out:
# np.float64(1299.008507)

# %%
df['amount'].sum()
# Out:
# np.float64(1049623.455648)

# %%
df['amount'].mean()
# Out:
# np.float64(999.6413863314284)

# %%
df['amount'].count()
# Out:
# np.int64(1050)

# %%
df['name'][df['amount'] == df['amount'].max()]
# Out:
# 773    John Smith
# Name: name, dtype: object

# %% [markdown]
# ##### Merge and join data

# %%
# Creating first DataFrame
df1 = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40]
})

# Creating second DataFrame
df2 = pd.DataFrame({
    'ID': [3, 4, 5, 6],
    'Salary': [50000, 60000, 70000, 80000]
})

# %%
df1
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 3   4    David   40

# %%
df2
# Out:
#    ID  Salary
# 0   3   50000
# 1   4   60000
# 2   5   70000
# 3   6   80000

# %%
# merge() & join()

# %%
pd.merge(df1, df2, on='ID', how='inner')
# Out:
#    ID     Name  Age  Salary
# 0   3  Charlie   35   50000
# 1   4    David   40   60000

# %%
pd.merge(df1, df2, on='ID', how='left')
# Out:
#    ID     Name  Age   Salary
# 0   1    Alice   25      NaN
# 1   2      Bob   30      NaN
# 2   3  Charlie   35  50000.0
# 3   4    David   40  60000.0

# %%
pd.merge(df1, df2, on='ID', how='right')
# Out:
#    ID     Name   Age  Salary
# 0   3  Charlie  35.0   50000
# 1   4    David  40.0   60000
# 2   5      NaN   NaN   70000
# 3   6      NaN   NaN   80000

# %%
pd.merge(df1, df2, on='ID', how='outer')
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0      NaN
# 1   2      Bob  30.0      NaN
# 2   3  Charlie  35.0  50000.0
# 3   4    David  40.0  60000.0
# 4   5      NaN   NaN  70000.0
# 5   6      NaN   NaN  80000.0

# %%
pd.merge(df1, df2)
# Out:
#    ID     Name  Age  Salary
# 0   3  Charlie   35   50000
# 1   4    David   40   60000

# %%
df1.merge(df2)
# Out:
#    ID     Name  Age  Salary
# 0   3  Charlie   35   50000
# 1   4    David   40   60000

# %%
# join()

# %%
df1
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35
# 3   4    David   40

# %%
df2
# Out:
#    ID  Salary
# 0   3   50000
# 1   4   60000
# 2   5   70000
# 3   6   80000

# %%
df3 = df1.set_index('ID')
df4 = df2.set_index('ID')

# %%
df3
# Out:
#        Name  Age
# ID
# 1     Alice   25
# 2       Bob   30
# 3   Charlie   35
# 4     David   40

# %%
df4
# Out:
#     Salary
# ID
# 3    50000
# 4    60000
# 5    70000
# 6    80000

# %%
df3.join(df4)
# Out:
#        Name  Age   Salary
# ID
# 1     Alice   25      NaN
# 2       Bob   30      NaN
# 3   Charlie   35  50000.0
# 4     David   40  60000.0

# %%
df3.join(df4, how='left')
# Out:
#        Name  Age   Salary
# ID
# 1     Alice   25      NaN
# 2       Bob   30      NaN
# 3   Charlie   35  50000.0
# 4     David   40  60000.0

# %%
df3.join(df4, how='inner')
# Out:
#        Name  Age  Salary
# ID
# 3   Charlie   35   50000
# 4     David   40   60000

# %%
df3.join(df4, how='right')
# Out:
#        Name   Age  Salary
# ID
# 3   Charlie  35.0   50000
# 4     David  40.0   60000
# 5       NaN   NaN   70000
# 6       NaN   NaN   80000

# %%
df3.join(df4, how='outer')
# Out:
#        Name   Age   Salary
# ID
# 1     Alice  25.0      NaN
# 2       Bob  30.0      NaN
# 3   Charlie  35.0  50000.0
# 4     David  40.0  60000.0
# 5       NaN   NaN  70000.0
# 6       NaN   NaN  80000.0

# %% [markdown]
# ##### Visualize data

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'Age': [25, 30, 35, 40, 29],
    'Salary': [50000, 60000, 70000, 80000, 55000]
}

df = pd.DataFrame(data)

df
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   40   80000
# 4     Emma   29   55000

# %%
import matplotlib

df.plot(kind="bar", x="Name", y="Salary", title="Salary by Name", xlabel="Name", ylabel="Salary")
# Out:
# <Axes: title={'center': 'Salary by Name'}, xlabel='Name', ylabel='Salary'>

# %%
df.plot(kind="line", x="Name", y="Salary", title="Salary by Name", xlabel="Name", ylabel="Salary", marker="o")
# Out:
# <Axes: title={'center': 'Salary by Name'}, xlabel='Name', ylabel='Salary'>

# %%
df.plot(kind="pie", y="Salary", title="Salary by Name", labels=df["Name"], startangle=90, autopct='%0.2f%%')
# Out:
# <Axes: title={'center': 'Salary by Name'}, ylabel='Salary'>
